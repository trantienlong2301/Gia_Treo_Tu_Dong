# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('image_8.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# if img == None:
#     print("no")

# %%
plt.imshow(img,cmap='gray')

# %%
mm=np.max(img)
img=img/mm*255

# %%
plt.imshow(img,cmap='gray')

# %%
a,th1 = cv2.threshold(img, 230, 255, cv2.THRESH_BINARY )
plt.imshow(th1,cmap='gray')
th1.shape
# Out:
# (240, 320)
